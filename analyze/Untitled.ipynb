# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("../build/results.csv", skiprows=1)

# %%
ground_1d_grid = df.loc[0].to_numpy()

# %%
len(ground_1d_grid)

# %%
ground_grid = np.array([])
L = 10
for i in range(L):
    a = ground_1d_grid[i*L: i*L + L-1]
    ground_grid = np.vstack((a,b))
# Out:
#   Cell In[30], line 5
#     b = ground_1d[]
#                   ^
# SyntaxError: invalid syntax
